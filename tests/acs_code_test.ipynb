# %% [markdown]
# # ACS Code Query Test
#
# This notebook tests the ACS code query functionality.

# %%
# Import necessary libraries (if any)
# Example: import pandas as pd

# Define test cases
test_codes = ["B01001_001E", "DP05_0001E"]

# Function to query ACS code (replace with actual implementation path)
# from your_module import query_acs_code 

def query_acs_code(code):
    # Placeholder for the actual query logic
    # Replace this with calling your actual function
    print(f"Querying code: {code}")
    # Example return, replace with actual result
    return f"Description for {code}"

# Run tests
for code in test_codes:
    description = query_acs_code(code)
    print(f"{code}: {description}")
